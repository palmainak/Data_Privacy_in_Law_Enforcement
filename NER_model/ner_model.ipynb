# %%
! pip install -U spacy -q

# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.7.4
# Location         /usr/local/lib/python3.10/dist-packages/spacy
# Platform         Linux-6.1.58+-x86_64-with-glibc2.35
# Python version   3.10.12
# Pipelines        en_core_web_sm (3.7.1)

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

nlp = spacy.blank("en") # load a new spacy model
db = DocBin() # create a DocBin object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
f = open('test_data.json')
TRAIN_DATA = json.load(f)

# %%
TRAIN_DATA
# Out:
# {'classes': ['DATE',
#   'PERSON',
#   'PLACE',
#   'CRIME NAME',
#   'CRIME ACT SECTION',
#   'ORGANISATION',
#   'ENTITY',
#   'AGE',
#   'TIME',
#   'POLICE RANK',
#   'POLICE STATION',
#   'DAY',
#   'YEAR'],
#  'annotations': [['Mangaluru: In a case of display of brutality, a purported video which captured a daughter-in-law brutally beating her octogenarian father-in-law with a steel walking stick has sent shockwaves across social media platforms.\r',
#    {'entities': [[0, 9, 'PLACE'],
#      [35, 44, 'CRIME NAME'],
#      [97, 113, 'CRIME NAME'],
#      [152, 171, 'ENTITY']]}],
#   ['The footage, which has swiftly gone viral, showcases an act of abuse that has sparked widespread condemnation and calls for justice among the civil society in Mangaluru.\r',
#    {'entities': [[4, 11, 'ENTITY'],
#      [56, 68, 'CRIME NAME'],
#      [159, 168, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['In the incident caught on CCTV, a 87-year-old man, Pa dmanabha Suvarna, was subjected to vicious beating by his daughter-in-law, Uma Shankari, in Kulshekar of Mangaluru. The assault, which occurred on March 9, involved the use of a walking stick, leaving the elderly victim severely injured.\r',
#    {'entities': [[26, 30, 'ENTITY'],
#      [34, 45, 'AGE'],
#      [51, 70, 'PERSON'],
#      [89, 104, 'CRIME NAME'],
#      [129, 141, 'PERSON'],
#      [146, 155, 'PLACE'],
#      [159, 169, 'PLACE'],
#      [174, 181, 'CRIME NAME'],
#      [201, 208, 'DATE'],
#      [232, 245, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Padmanabha Suvarna, a resident of Mangaluru, is now receiving treatment for his injuries at a private hospital.\r',
#    {'entities': [[0, 18, 'PERSON'], [34, 43, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ["The accused, Uma Shankari, currently employed as an officer of the electricity provider company at Attavar, was taken into custody following a complaint filed by the victim's daughter.\r",
#    {'entities': [[13, 25, 'PERSON'], [99, 106, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ["The accused's husband, who is the son of the victim, is reported to be working abroad. The incident has sent shockwaves through the local community, prompting concerns about the well-being of the elderly and the need for stringent measures against domestic violence.\r",
#    {'entities': [[248, 265, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ["Uma Shankari, employed as an officer with the Karnataka Electricity Board (KEB) at Attavar, was swiftly arrested after a complaint was lodged by the victim's daughter.\r",
#    {'entities': [[0, 12, 'PERSON'],
#      [46, 79, 'ORGANISATION'],
#      [83, 90, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['The doctor treating the Suvarna told PTI that there were multiple injuries on the body of the victim including a head injury which he received during a fall on a wooden sofa at the site of the attack.\r',
#    {'entities': [[24, 31, 'PERSON'],
#      [37, 40, 'ORGANISATION'],
#      [162, 173, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PUNE: A 30-year-old man with a criminal record was shot twice in the head and later hacked to death with billhooks by eight assailants at an eatery on the Indapur bypass road, about 140km from the city on the highway to Solapur, around 8pm on Saturday.\r',
#    {'entities': [[0, 4, 'PLACE'],
#      [8, 19, 'AGE'],
#      [105, 114, 'ENTITY'],
#      [155, 174, 'PLACE'],
#      [220, 227, 'PLACE'],
#      [236, 239, 'TIME'],
#      [243, 251, 'DAY']]}],
#   ['\r', {'entities': []}],
#   ['Pune rural police identified the victim as Avinash Dhanve, a resident of Wadmukhwadi near Alandi. "Prima facie, old rivalry between two criminal gangs in Wadmukhwadi has been established as the murder motive. So far, 10 suspects have been established in the murder," deputy superintendent of police (Baramati division) Sudarshan Rathod said.\r',
#    {'entities': [[0, 17, 'POLICE STATION'],
#      [43, 57, 'PERSON'],
#      [73, 84, 'PLACE'],
#      [90, 97, 'PLACE'],
#      [154, 165, 'PLACE'],
#      [194, 200, 'CRIME NAME'],
#      [258, 264, 'CRIME NAME'],
#      [267, 298, 'POLICE RANK'],
#      [300, 317, 'POLICE STATION'],
#      [319, 335, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['"We have ascertained the identities of the attackers and have deployed five police teams to arrest them," he added.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['"Dhanve had five previous criminal cases, including that of a murder, to his name and was detained under the stringent Maharashtra Control of Organised Crime Act (MCOCA)," Rathod said, adding that he was released on bail a month ago.\r',
#    {'entities': [[1, 7, 'PERSON'],
#      [62, 68, 'CRIME NAME'],
#      [119, 169, 'CRIME ACT SECTION'],
#      [172, 178, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['On Saturday, Dhanve and three of his associates, who were going to Pandhapur in a car, stopped at an eatery on Indapur bypass for dinner.\r',
#    {'entities': [[3, 11, 'DAY'],
#      [13, 19, 'PERSON'],
#      [67, 76, 'PLACE'],
#      [82, 85, 'ENTITY'],
#      [111, 125, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ETAWAH/KANPUR: The Uttar Pradesh police on Thursday recovered the body of a 20-year-old student from Saifai Medical College near Sonai Bridge, raising concerns of a possible heinous crime.\r',
#    {'entities': [[0, 13, 'PLACE'],
#      [19, 39, 'POLICE STATION'],
#      [43, 51, 'DAY'],
#      [76, 87, 'AGE'],
#      [101, 123, 'ORGANISATION'],
#      [129, 141, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['The victim, identified as Priya Mishra, a first-year paramedical student from Auraiya, was found dead with severe injuries, indicating foul play.\r',
#    {'entities': [[26, 38, 'PERSON'],
#      [78, 85, 'PLACE'],
#      [135, 144, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['SSP Sanjay Kumar Verma revealed that the body may have been dumped at the location as no blood traces were found so far.\r',
#    {'entities': [[0, 3, 'POLICE RANK'], [4, 22, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['"Body of a 20-year-old student named Priya Mishra has been found. She is a resident of Auraiya. Upon investigation, it has been found that the girl handed over her mobile phone to her friend in the afternoon, before going missing. It was also discovered that she had been involved in a recent altercation with someone," SSP Sanjay Kumar said.\r',
#    {'entities': [[11, 22, 'AGE'],
#      [37, 49, 'PERSON'],
#      [87, 95, 'PLACE'],
#      [164, 176, 'ENTITY'],
#      [320, 323, 'POLICE RANK'],
#      [324, 336, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['The investigation is ongoing, and all angles will be thoroughly examined, according to the Saifai police.\r',
#    {'entities': [[91, 104, 'POLICE STATION']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ["NEW DELHI: Two individuals have been arrested by the police in connection with the murder of Nafe Singh Rathee, the chief of Haryana's Indian National Lok Dal (INLD).\r",
#    {'entities': [[0, 9, 'PLACE'],
#      [83, 89, 'CRIME NAME'],
#      [93, 110, 'PERSON'],
#      [125, 132, 'PLACE'],
#      [135, 165, 'ORGANISATION']]}],
#   ['\r', {'entities': []}],
#   ['The arrest was made in a joint operation conducted by the Jhajjar police, Delhi Police Special Cell, and the Haryana Special Task Force (STF) in Goa.\r',
#    {'entities': [[58, 72, 'POLICE STATION'],
#      [74, 99, 'ORGANISATION'],
#      [109, 141, 'ORGANISATION'],
#      [145, 148, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['The suspects, Saurav and Ashish, who are residents of Delhi, are believed to have ties to the UK-based Kapil Sangwan gang.\r',
#    {'entities': [[14, 20, 'PERSON'],
#      [25, 31, 'PERSON'],
#      [54, 59, 'PLACE'],
#      [103, 116, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['Efforts are currently underway to locate two other individuals involved in the shooting. Rathee was fatally shot on February 25 near a railway crossing in Bahadurgarh, Jhajjar.\r',
#    {'entities': [[89, 95, 'PERSON'],
#      [116, 127, 'DATE'],
#      [155, 166, 'PLACE'],
#      [168, 175, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ["Reports indicate that the assailants arrived in a car and opened fire, resulting in Rathee's death along with that of a party worker.\r",
#    {'entities': [[50, 53, 'ENTITY'], [84, 90, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ["On February 28, Kapil Sangwan, a British-based gangster, claimed responsibility for Rathee's murder on social media. He alleged that Rathee had colluded with Manjeet Mahal's brother, Sanjay, to seize properties and had aided Manjeet in the killing of his brother-in-law and friends.\r",
#    {'entities': [[3, 14, 'DATE'],
#      [16, 29, 'PERSON'],
#      [84, 90, 'PERSON'],
#      [93, 99, 'CRIME NAME'],
#      [133, 139, 'PERSON'],
#      [158, 173, 'PERSON'],
#      [183, 189, 'PERSON'],
#      [194, 210, 'CRIME NAME'],
#      [225, 232, 'PERSON'],
#      [240, 247, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['The gangster further claimed that Rathee had captured and executed numerous individuals during his time in power, a fact well-known in Bahadurgarh.\r',
#    {'entities': [[34, 40, 'PERSON'], [135, 146, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['RUDRAPUR: Three persons have been arrested for their alleged involvement in a double murder in Kashipur, Udham Singh Nagar, on Thursday. Police said Garv Mehra, Vivek Kumar, and Deepak Kumar alias Hooda attacked Chaman Saini and his friend Sumit near Chaiti Tiraha in Kashipur. The fourth person involved in the attack, Kartik Sharma, is on the run.\r',
#    {'entities': [[0, 8, 'PLACE'],
#      [85, 91, 'CRIME NAME'],
#      [95, 103, 'PLACE'],
#      [105, 122, 'PLACE'],
#      [127, 136, 'DAY'],
#      [149, 159, 'PERSON'],
#      [161, 172, 'PERSON'],
#      [178, 190, 'PERSON'],
#      [197, 202, 'PERSON'],
#      [212, 224, 'PERSON'],
#      [240, 245, 'PERSON'],
#      [251, 264, 'PLACE'],
#      [268, 277, 'PLACE'],
#      [320, 333, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ["The situation escalated when Chaman's brother Akash Saini and his friend Ajay Kashyap intervened to rescue them. The assailants, armed with sharp weapons, inflicted fatal injuries on Akash and Ajay, leaving them in a critical condition.\r",
#    {'entities': [[29, 35, 'PERSON'],
#      [46, 57, 'PERSON'],
#      [73, 85, 'PERSON'],
#      [140, 153, 'ENTITY'],
#      [183, 188, 'PERSON'],
#      [193, 197, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['U S Nagar SSP Manjunath T C said, "We arrested Vivek and Garv on Saturday while Hooda was nabbed near Parmanandpur on Sunday. The search for Kartik Sharma is ongoing." He added that Hooda confessed he had hidden the blood-stained shirt and the knife used in the incident. The police have recovered the evidence from Hooda\'s residence.\r',
#    {'entities': [[0, 9, 'PLACE'],
#      [10, 13, 'POLICE RANK'],
#      [14, 27, 'PERSON'],
#      [47, 52, 'PERSON'],
#      [57, 61, 'PERSON'],
#      [65, 73, 'DAY'],
#      [80, 85, 'PERSON'],
#      [102, 114, 'PLACE'],
#      [118, 125, 'DAY'],
#      [141, 154, 'PERSON'],
#      [182, 187, 'PERSON'],
#      [216, 235, 'ENTITY'],
#      [244, 249, 'ENTITY'],
#      [316, 321, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['VISAKHAPATNAM: The missing photographer from Visakhapatnam was found murdered in Ravulapalem of Dr BR Ambedkar Konaseema district. The shocking incident came to light on Sunday and the motive was to rob his expensive photography equipment.The victim was identified as Pothina Sai Vijay Pawan Kalyan Kumar (popular as Sai Kumar), a resident of Bakkanapalem under PM Palem police station limits in Vizag city. Known for taking online bookings for weddings and other events, Sai Kumar received a photography appointment from a client Shanmukh Teja, who befriended Sai on the social media platform Instagram.\r',
#    {'entities': [[0, 13, 'PLACE'],
#      [45, 58, 'PLACE'],
#      [69, 77, 'CRIME NAME'],
#      [81, 92, 'PLACE'],
#      [96, 130, 'PLACE'],
#      [170, 176, 'DAY'],
#      [268, 304, 'PERSON'],
#      [317, 326, 'PERSON'],
#      [343, 355, 'PLACE'],
#      [362, 385, 'POLICE STATION'],
#      [396, 401, 'PLACE'],
#      [472, 481, 'PERSON'],
#      [531, 544, 'PERSON'],
#      [561, 564, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['Shanmukh was aware that Sai has high-end photography equipment which costs over Rs15 lakh. Shanmukh informed Sai that there was a massive photography event in Ravulapalem which would fetch a good amount.\r',
#    {'entities': [[0, 8, 'PERSON'],
#      [24, 27, 'PERSON'],
#      [32, 62, 'ENTITY'],
#      [91, 99, 'PERSON'],
#      [109, 112, 'PERSON'],
#      [159, 170, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['Sai Kumar informed his parents about his trip to Ravulapalem and set out with his photography equipment on Feb 26. However, upon reaching Rajahmundry, Shanmukh and his friend Raju took Sai in a car to Vemagiri location.\r',
#    {'entities': [[0, 9, 'PERSON'],
#      [49, 60, 'PLACE'],
#      [82, 103, 'ENTITY'],
#      [107, 114, 'DATE'],
#      [138, 149, 'PLACE'],
#      [151, 159, 'PERSON'],
#      [175, 179, 'PERSON'],
#      [185, 188, 'PERSON'],
#      [194, 197, 'ENTITY'],
#      [201, 209, 'PLACE']]}],
#   ['Suspecting that he was in danger, Sai Kumar shared the registration number of the car and Shanmukh’s contact number to his parents. Alarmed by their son’s disappearance for more than three days, Sai Kumar’s parents filed a missing complaint with the PM Palem police in Vizag city on February 29.\r',
#    {'entities': [[34, 43, 'PERSON'],
#      [82, 85, 'ENTITY'],
#      [90, 100, 'PERSON'],
#      [195, 206, 'PERSON'],
#      [250, 265, 'POLICE STATION'],
#      [269, 274, 'PLACE'],
#      [283, 294, 'DATE']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ["MUMBAI: A 40-year-old woman has been taken into custody by the police for the alleged murder of her 19-year-old daughter, Bhoomika Bagade. Initially, the accused Tina Bagade tried to pass off the incident as an accidental death due to her daughter's asthma. However, the truth emerged when the post-mortem report revealed that Bhoomika had been strangled during a confrontation with her mother on Monday morning.\r",
#    {'entities': [[0, 6, 'PLACE'],
#      [10, 21, 'AGE'],
#      [86, 92, 'CRIME NAME'],
#      [100, 111, 'AGE'],
#      [122, 138, 'PERSON'],
#      [162, 173, 'PERSON'],
#      [294, 312, 'ENTITY'],
#      [327, 335, 'PERSON'],
#      [397, 403, 'DAY']]}],
#   ['\r', {'entities': []}],
#   ['The Nirmal Nagar police had initially registered the case as an accidental death report (ADR) based on Tina\'s account. However, the post-mortem report prompted further investigation, and the police discovered the motive behind the murder. "She claimed her finger was injured while trying to escape and seek help from her neighbours. The post-mortem report helped us uncover the truth," said a police officer from the Nirmal Nagar police station.\r',
#    {'entities': [[4, 23, 'POLICE STATION'],
#      [64, 93, 'ENTITY'],
#      [103, 107, 'PERSON'],
#      [132, 150, 'ENTITY'],
#      [231, 238, 'CRIME NAME'],
#      [337, 355, 'ENTITY'],
#      [417, 444, 'POLICE STATION']]}],
#   ['\r', {'entities': []}],
#   ["A case under the Indian Penal Code sections 302 (murder) and 201 (Causing disappearance of evidence) against Tina. She is in police custody till March 16. A suo motu case was registered against Tina and the DCP (Zone VIII) Dikshit Gedam supervised the Nirmal Nagar police team--ACP Suhas Kamble, senior inspector Shrimant Shinde, inspector Abdul Rauf Shaikh, and staff--learned from doctors that there were strangulation marks on the victim's neck.\r",
#    {'entities': [[17, 56, 'CRIME ACT SECTION'],
#      [61, 100, 'CRIME ACT SECTION'],
#      [109, 114, 'PERSON'],
#      [145, 154, 'DATE'],
#      [194, 198, 'PERSON'],
#      [207, 222, 'POLICE RANK'],
#      [223, 236, 'PERSON'],
#      [252, 271, 'POLICE STATION'],
#      [278, 281, 'POLICE RANK'],
#      [282, 294, 'PERSON'],
#      [296, 312, 'POLICE RANK'],
#      [313, 328, 'PERSON'],
#      [330, 339, 'POLICE RANK'],
#      [340, 357, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['A police officer said Tina revealed that her daughter was involved with a drug addict. "The accused was against their relationship.\r',
#    {'entities': [[22, 26, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['Bhoomika\'s younger brother and sister witnessed them fighting. The situation escalated when Bhoomika bit her mother\'s index finger, causing severe injury. Tina, in self-defense, strangled her daughter during the altercation, trying to portray it as an asthma attack," said the officer.\r',
#    {'entities': [[0, 8, 'PERSON'],
#      [92, 100, 'PERSON'],
#      [101, 104, 'CRIME NAME'],
#      [155, 159, 'PERSON'],
#      [178, 187, 'CRIME NAME'],
#      [259, 265, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['Police said the accused is a housemaid and her husband died of suicide two years ago due to financial crisis.\r',
#    {'entities': [[63, 70, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ["TIRUPATI: Telugu Desam party's national general secretary and former minister Nara Lokesh assured Dr Suneetha Narreddy that her father YS Vivekananda Reddy's killers will be sent to jail and justice will finally be rendered to her family immediately after the TDP govt comes back to power in the state in the next two months.\r",
#    {'entities': [[0, 8, 'PLACE'],
#      [10, 28, 'ORGANISATION'],
#      [78, 89, 'PERSON'],
#      [98, 118, 'PERSON'],
#      [135, 157, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['Addressing an impressive gathering at the Shankaravam public meetings held at Hindupur, Madakasira and Penukonda at the Hindupur parliamentary constituency on Thursday, Lokesh recalled that Suneetha Reddy has been demanding for justice to prevail in the Viveka murder case.\r',
#    {'entities': [[78, 86, 'PLACE'],
#      [88, 98, 'PLACE'],
#      [103, 112, 'PLACE'],
#      [120, 128, 'PLACE'],
#      [159, 167, 'DAY'],
#      [169, 175, 'PERSON'],
#      [190, 204, 'PERSON'],
#      [254, 260, 'PERSON'],
#      [261, 267, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['"Within two months from now, the Telugu Desam party will form the govt and I promise Suneetha that her father\'s killers will definitely be sent to jail", Lokesh reiterated.\r',
#    {'entities': [[33, 51, 'ORGANISATION'],
#      [85, 93, 'PERSON'],
#      [154, 160, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['Ridiculing the commitment of the YSRCP for the upliftment of the BC communities, Lokesh alleged that the YSRCP govt booked false cases on 26000 BCs and was responsible for the killings of more than 300 people belonging to the BC communities.\r',
#    {'entities': [[33, 38, 'ORGANISATION'],
#      [81, 87, 'PERSON'],
#      [105, 110, 'ORGANISATION'],
#      [123, 134, 'CRIME NAME'],
#      [176, 184, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['"But be assured, the Telugu Desam party which is known for its strong inclination towards the BCs will quash all the false cases registered by this govt in the last five years", the TDP national secretary assured.\r',
#    {'entities': [[21, 39, 'ORGANISATION'],
#      [117, 128, 'CRIME NAME'],
#      [182, 185, 'ORGANISATION']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ["TIRUPATI: A 56-year-old wife, who witnessed her 59-year-old husband's brutal murder, died of cardiac arrest in Anantapur late on Sunday.\r",
#    {'entities': [[0, 8, 'PLACE'],
#      [12, 23, 'AGE'],
#      [48, 59, 'AGE'],
#      [70, 83, 'CRIME NAME'],
#      [111, 120, 'PLACE'],
#      [129, 135, 'DAY']]}],
#   ['The deceased were identified as Murthy Rao Gokhale and his wife, Shobha Gokhale.\r',
#    {'entities': [[32, 50, 'PERSON'], [65, 79, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['According to Anantapur I Town Circle Inspector Reddeppa, the tragic incident unfolded at an apartment in LIC Colony, opposite the JNTU campus in Anantapur.\r',
#    {'entities': [[13, 22, 'PLACE'],
#      [25, 46, 'POLICE RANK'],
#      [47, 55, 'PERSON'],
#      [105, 115, 'PLACE'],
#      [130, 141, 'PLACE'],
#      [145, 154, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['The deceased, Murthy Rao Gokhale, was working as a guest faculty at SK University and had earlier served as the principal of Ananta Lakshmi Engineering College.\r',
#    {'entities': [[14, 32, 'PERSON'],
#      [68, 81, 'ORGANISATION'],
#      [125, 159, 'ORGANISATION']]}],
#   ['\r', {'entities': []}],
#   ['Police said the accused was identified as Adithya, who happened to be the niece of the deceased.\r',
#    {'entities': [[42, 49, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['KOZHIKODE: Police arrested Kondotty native Mujeeb Rahman (49), a history-sheeter who has around 60 criminal cases registered in his name, for killing Perambra native Anu K (24) on Monday morning and taking her gold ornaments. District police chief (Koz Rural) Aravind Sukumar said Rahman, who was riding a stolen motorcycle, saw Anu hurriedly walking on the road to meet her husband who was waiting at the next junction to take him to a hospital. He offered her a lift.\r',
#    {'entities': [[0, 9, 'PLACE'],
#      [27, 35, 'PLACE'],
#      [43, 56, 'PERSON'],
#      [57, 61, 'AGE'],
#      [150, 158, 'PLACE'],
#      [166, 171, 'PERSON'],
#      [172, 176, 'AGE'],
#      [180, 186, 'DAY'],
#      [210, 225, 'ENTITY'],
#      [226, 247, 'POLICE RANK'],
#      [249, 258, 'PLACE'],
#      [260, 275, 'PERSON'],
#      [281, 287, 'PERSON'],
#      [306, 323, 'ENTITY'],
#      [329, 332, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['"When they reached a nearby stream, he stopped saying he wanted to urinate and when she got down from the vehicle, he pushed her into the stream, dragged her down the culvert, kept her head down in the waters and killed her. He escaped with her golden bracelet, chain, anklet and rings," he said.\r',
#    {'entities': [[106, 113, 'ENTITY'],
#      [213, 219, 'CRIME NAME'],
#      [245, 260, 'ENTITY'],
#      [262, 267, 'ENTITY'],
#      [269, 275, 'ENTITY'],
#      [280, 285, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Residents found her body in the canal on Tuesday noon and police became suspicious as her ornaments were missing and there wasn\'t enough water in the stream for drowning. Police said Rahman forced her head underwater by stamping on her. A resident gave a statement that she saw Anu on a stranger\'s motorcycle and this strengthened their suspicions. "The autopsy report showed there were pressure marks on her body, following his attempts to restrain her and there was mud in her airways which pointed to pressing her head in the streambed," Sukumar said.\r',
#    {'entities': [[41, 48, 'DAY'],
#      [90, 99, 'ENTITY'],
#      [183, 189, 'PERSON'],
#      [278, 281, 'PERSON'],
#      [298, 308, 'ENTITY'],
#      [354, 368, 'ENTITY'],
#      [541, 548, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['KOLKATA: At least 10 people were killed and 17 injured when a five-storey building, being constructed illegally in a congested area in Garden Reach, collapsed on the intervening night of Sunday and Monday.\r',
#    {'entities': [[0, 7, 'PLACE'],
#      [33, 39, 'CRIME NAME'],
#      [62, 82, 'ENTITY'],
#      [102, 111, 'CRIME NAME'],
#      [135, 147, 'PLACE'],
#      [187, 193, 'DAY'],
#      [198, 204, 'DAY']]}],
#   ['\r', {'entities': []}],
#   ['Till late on Monday, a search was on for three people who are still missing under mounds of rubble.\r',
#    {'entities': [[13, 19, 'DAY']]}],
#   ['\r', {'entities': []}],
#   ['The dead and the injured were mostly residents of an adjoining slum; at least two of them were labourers working on construction of the building.\r',
#    {'entities': [[136, 144, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Building promoter Md Wasim alias Wasi was held and charged with multiple sections, including murder and attempt to murder.\r',
#    {'entities': [[18, 26, 'PERSON'],
#      [33, 37, 'PERSON'],
#      [93, 99, 'CRIME NAME'],
#      [104, 121, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['Under fire over its laxity, Kolkata Municipal Corporation (KMC) show-caused three civic engineers from the local borough and identified six other illegal buildings in the vicinity. One of them, which was tilting dangerously, will be razed immediately.\r',
#    {'entities': [[28, 63, 'ORGANISATION'],
#      [146, 153, 'CRIME NAME'],
#      [154, 163, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BENGALURU: The mystery shrouding the death of a 27-year-old Uzbek woman inside her room at Jagadish Hotel on Sankey Road has been unravelled. \r',
#    {'entities': [[0, 9, 'PLACE'],
#      [48, 59, 'AGE'],
#      [91, 105, 'PLACE'],
#      [109, 120, 'PLACE']]}],
#   ['\r', {'entities': []}],
#   ['Two of the hotel’s housekeeping staff were arrested on Friday on charges of murdering her.\r',
#    {'entities': [[55, 61, 'DAY'], [76, 85, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['The accused thought the foreign woman, identified as Zarina Utkirovna, was carrying lots of cash and robbing her would make them rich instantly.\r',
#    {'entities': [[53, 69, 'PERSON'], [92, 96, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Zarina, who had checked into Jagadish Hotel on March after flying from Delhi and was staying in a room on the second floor, was found dead on the night of March 13 with injuries on her face and bleeding from the nose.Her iPhone and cash was missing from the room.\r',
#    {'entities': [[0, 6, 'PERSON'],
#      [29, 43, 'PLACE'],
#      [71, 76, 'PLACE'],
#      [155, 163, 'DATE'],
#      [221, 227, 'ENTITY'],
#      [232, 236, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Following the investigation, the city police arrested 22-year-old Amrit Sona and 26-year old Robert, both hailing from Assam. the cops recovered the stolen phone and Rs. 20,000 cash from them.\r',
#    {'entities': [[54, 65, 'AGE'],
#      [66, 76, 'PERSON'],
#      [81, 92, 'AGE'],
#      [93, 99, 'PERSON'],
#      [119, 125, 'PLACE'],
#      [149, 161, 'ENTITY'],
#      [170, 181, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Further, police said the doctors who carried out the autopsy said there was no signs of sexual assault or rape on the victim.\r',
#    {'entities': [[88, 102, 'CRIME NAME'], [106, 110, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ["MUMBAI: Observing that her husband giving time and money to his mother cannot be considered as 'domestic violence', a sessions court dismissed a 53-year-old Mantralaya employee's appeal against a magistrate court rejecting her domestic violence complaint against her ex husband and in-laws.\r",
#    {'entities': [[0, 6, 'PLACE'],
#      [51, 56, 'ENTITY'],
#      [95, 113, 'CRIME NAME'],
#      [145, 156, 'AGE'],
#      [227, 244, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ["The woman had filed an appeal before the sessions court in 2016, the year after a magistrate's court rejected her plea for relief under the Domestic Violence Act. The woman had filed the complaint in 2008.\r",
#    {'entities': [[59, 63, 'YEAR'],
#      [140, 162, 'CRIME ACT SECTION'],
#      [200, 204, 'YEAR']]}],
#   ['\r', {'entities': []}],
#   ['The woman had submitted that she had married the accused in 1992 and delivered a daughter two years later. \r',
#    {'entities': [[60, 64, 'YEAR']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BENGALURU/NEW DELHI: Arjuna award-winning Indian hockey player Varun Kumar has been booked under the stringent POCSO act by the Bengaluru Police after a woman accused the defender of sexually abusing her multiple times when she was a minor.\r',
#    {'entities': [[0, 19, 'PLACE'],
#      [42, 48, 'PLACE'],
#      [49, 55, 'ENTITY'],
#      [63, 74, 'PERSON'],
#      [111, 120, 'CRIME ACT SECTION'],
#      [128, 144, 'POLICE STATION'],
#      [183, 199, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['The 22-year-old, in her complaint filed on Monday, said that she came in contact with Varun in 2018 through Instagram, and the player raped her on multiple occasions promising her of marriage when she was 17.\r',
#    {'entities': [[4, 15, 'AGE'],
#      [43, 49, 'DAY'],
#      [86, 91, 'PERSON'],
#      [95, 99, 'YEAR'],
#      [134, 139, 'CRIME NAME']]}],
#   ['\r', {'entities': []}],
#   ['She said Varun was training at the Sports Authority of India (SAI) centre in Bengaluru when she met him. Varun, who was awarded the Arjuna in 2021, was recently promoted as a DSP in Punjab Police.\r',
#    {'entities': [[9, 14, 'PERSON'],
#      [35, 73, 'ORGANISATION'],
#      [77, 86, 'PLACE'],
#      [105, 110, 'PERSON'],
#      [142, 146, 'YEAR'],
#      [175, 178, 'POLICE RANK'],
#      [182, 195, 'POLICE STATION']]}],
#   ['\r', {'entities': []}],
#   ['"Based on the complaint received from the woman, we have registered a case on Monday against the Hockey player under appropriate section of Protection of Children from Sexual Offences Act and sections 376 (rape) and 420 (cheating and dishonestly inducing delivery of property) of the Indian Penal Code," a senior Bengaluru Police officer said on Tuesday.\r',
#    {'entities': [[78, 84, 'DAY'],
#      [97, 103, 'ENTITY'],
#      [140, 211, 'CRIME ACT SECTION'],
#      [216, 301, 'CRIME ACT SECTION'],
#      [313, 322, 'PLACE'],
#      [346, 353, 'DAY']]}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['DUMKA/RANCHI: On a biking trip across India, a 35-year-old Spanish tourist was allegedly gang-raped, and her husband brutally assaulted by seven youths in Jharkhand’s Dumka district late on Friday. The incident in Kurumahat area under Hansdiha police station went viral on the internet as the survivor, along with her husband, took to Instagram to vent their ordeal in a video message.\r',
#    {'entities': [[0, 12, 'PLACE'],
#      [38, 43, 'PLACE'],
#      [47, 58, 'AGE'],
#      [89, 99, 'CRIME NAME'],
#      [117, 135, 'CRIME NAME'],
#      [190, 197, 'DAY'],
#      [214, 223, 'PLACE'],
#      [235, 258, 'POLICE STATION']]}],
#   ['\r', {'entities': []}],
#   ['“Something has happened to us that we would not wish on anyone, seven men have raped me. They have beaten us and robbed us. Although, not many things, because they wanted to rape me. We are in hospital with the police, it happened tonight here in India,” the woman said in her video message with her visibly distraught husband by her side. Dumka SP Pitamber Singh Kherwar said: “All the accused have been identified and four have been arrested. They have confessed.” Around 11pm, the woman stopped a police patrol van in the area and pleaded for help.\r',
#    {'entities': [[79, 84, 'CRIME NAME'],
#      [99, 105, 'CRIME NAME'],
#      [113, 119, 'CRIME NAME'],
#      [174, 178, 'CRIME NAME'],
#      [247, 252, 'PLACE'],
#      [340, 345, 'PLACE'],
#      [346, 348, 'POLICE RANK'],
#      [349, 371, 'PERSON'],
#      [474, 478, 'TIME'],
#      [500, 517, 'ENTITY']]}],
#   ['\r', {'entities': []}],
#   ['Seeing her bruises and her husband’s injuries, police immediately took her to a hospital where she told doctors that she was raped. A medical examination confirmed sexual assault. “Prima facie, it’s a case of rape. They were camping in a semi-forested area, around 2km from the main road. They were also carrying their tent when they were waylaid,” an investigator said.\r',
#    {'entities': [[125, 131, 'CRIME NAME'],
#      [164, 179, 'CRIME NAME'],
#      [209, 214, 'CRIME NAME'],
#      [319, 323, 'ENTITY']]}],
#   ['“The couple has been kept at a secured location following medico-legal procedures. Their statements are being recorded before a magistrate under Section 164 of the CrPC,” said Dumka deputy commissioner Anjaneyulu Dodde.\r',
#    {'entities': [[145, 168, 'CRIME ACT SECTION'],
#      [176, 181, 'PLACE'],
#      [182, 201, 'POLICE RANK'],
#      [202, 218, 'PERSON']]}],
#   ['\r', {'entities': []}],
#   ['Police in a statement said the Spanish nationals reached Kurumahat (Dumka) from West Bengal at 5pm on Friday and were bound for Nepal.\r',
#    {'entities': [[57, 66, 'PLACE'],
#      [68, 73, 'PLACE'],
#      [80, 91, 'PLACE'],
#      [95, 98, 'TIME'],
#      [102, 108, 'DAY'],
#      [128, 133, 'PLACE']]}],
#   ['', {'entities': []}]]}

# %%
for text, annot in tqdm(TRAIN_DATA['annotations']):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents
    db.add(doc)

db.to_disk("./training_data.spacy") # save the docbin object
# Out:
# 100%|██████████| 214/214 [00:00<00:00, 2512.90it/s]

# %%
! python -m spacy init config config.cfg --lang en --pipeline ner --optimize efficiency
# Out:
# ✘ The provided output file already exists. To force overwriting the
# config file, set the --force or -F flag.

# %%
! python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     53.85    0.00    0.00    0.00    0.00
#   4     200       2237.31   3445.96   68.36   71.23   65.72    0.68
#  11     400        370.95   1128.00   94.06   94.30   93.81    0.94
#  19     600        210.68    361.03   98.84   98.97   98.71    0.99
#  29     800        343.28    215.85   99.74   99.74   99.74    1.00
#  41    1000         43.52     21.35  100.00  100.00  100.00    1.00
#  56    1200        101.45     47.04  100.00  100.00  100.00    1.00
#  75    1400         83.19     23.29  100.00  100.00  100.00    1.00
#  98    1600        259.87     74.89  100.00  100.00  100.00    1.00
# 127    1800         65.23     20.16  100.00  100.00  100.00    1.00
# 162    2000        383.71     65.27  100.00  100.00  100.00    1.00
# 205    2200        270.21     58.17  100.00  100.00  100.00    1.00
# 255    2400         44.56      9.46  100.00  100.00  100.00    1.00
# 305    2600         31.81      5.50  100.00  100.00  100.00    1.00
# ✔ Saved pipeline to output directory
# model-last

# %%
nlp_ner = spacy.load("/content/model-best")

# %%
doc = nlp_ner('''A 22-year-old man was arrested on Saturday for allegedly raping a woman here and threatening to upload her private video online, police said. Rahul Yadav, a resident of Handia in Prayagraj district, was booked on Friday under charges of rape and criminal intimidation for allegedly raping a 20-year-old woman.
He was arrested from near Gyanpur-Gopiganj tri-section here, police said. Gyanpur Police Station SHO Vinod Kumar Tiwari Yadav used to talk to the woman while visiting his elder's brother's in-laws who live in her village.

On March 3, he took her on a motorcycle to a place and raped her and also made a video of it, he said. According to police, after the incident, he blackmailed her into having sex with him several times till March 5 using the video.

Tiwari said the victim herself approached police on Friday evening and lodged a complaint against Yadav. The medical examination of the woman is yet to be conducted, the SHO said.''')

# %%
spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#  man was arrested on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DAY</span>
# </mark>
#  for allegedly raping a woman here and threatening to upload her private video online, police said.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rahul Yadav
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a resident of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Handia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PLACE</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prayagraj
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PLACE</span>
# </mark>
#  district, was booked on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DAY</span>
# </mark>
#  under charges of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME NAME</span>
# </mark>
#  and criminal intimidation for allegedly raping a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#  woman.<br>He was arrested from near
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gyanpur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PLACE</span>
# </mark>
# -
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gopiganj
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tri-section here, police said.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gyanpur Police
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POLICE STATION</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Station SHO Vinod Kumar Tiwari Yadav
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  used to talk to the woman while visiting his elder's brother's in-laws who live in her village.<br><br>On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he took her on a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     motorcycle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  to a place and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     raped
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME NAME</span>
# </mark>
#  her and also made a video of it, he said. According to police, after the incident, he blackmailed her into having sex with him several times till
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  using the video.<br><br>Tiwari said the victim herself approached police on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DAY</span>
# </mark>
#  evening and lodged a complaint against
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yadav.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  The medical examination of the woman is yet to be conducted, the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SHO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISATION</span>
# </mark>
#  said.</div></span>

# %%
doc = nlp_ner('''A 17-year-old girl was kidnapped from the Ubhaon area of Uttar Pradesh's Ballia district and was taken to Karnataka, where she was raped for almost two months. She was rescued by police, officials said on Wednesday.

The accused man was also arrested on Tuesday and sent to jail, they said.

The girl was allegedly abducted by a 20-year-old man from her village on the night of August 14. On the complaint of the girl's mother, a case was registered under sections 363 (kidnapping) and 366 (kidnapping or inducing a woman to compel for marriage) of the Indian Penal Code (IPC) on September 11, Ubhaon SHO Rajiv Mishra said.

On Tuesday, the police rescued the girl from near Bilthra Roadways and arrested the accused, he said.

In her statement to the police, the girl said the accused kidnapped and took her to Karnataka where he raped her for almost two months, the officer said.

Based on the statement, the police have added Section 376 (rape) of the IPC and provisions of the Protection of Children from Sexual Offenses (POCSO) Act in the case, he added.''')

# %%
spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#  girl was
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kidnapped
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME NAME</span>
# </mark>
#  from the Ubhaon area of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uttar Pradesh's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POLICE STATION</span>
# </mark>
#  Ballia district and was taken to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PLACE</span>
# </mark>
# , where she was
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     raped
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME NAME</span>
# </mark>
#  for almost two months. She was rescued by police, officials said on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DAY</span>
# </mark>
# <br><br>The accused man was also arrested on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DAY</span>
# </mark>
#  and sent to jail, they said.<br><br>The girl was allegedly abducted by a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#  man from her village on the night of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 14.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  On the complaint of the girl's mother, a case was registered under sections 363 (kidnapping) and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     366 (kidnapping or inducing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME ACT SECTION</span>
# </mark>
#  a woman to compel for marriage) of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian Penal Code
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME ACT SECTION</span>
# </mark>
#  (IPC) on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ubhaon SHO Rajiv Mishra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said.<br><br>On
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DAY</span>
# </mark>
# , the police rescued the girl from near
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bilthra Roadways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PLACE</span>
# </mark>
#  and arrested the accused, he said.<br><br>In her statement to the police, the girl said the accused kidnapped and took her to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PLACE</span>
# </mark>
#  where he
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     raped
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME NAME</span>
# </mark>
#  her for almost two months, the officer said.<br><br>Based on the statement, the police have added
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Section 376 (rape)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME ACT SECTION</span>
# </mark>
#  of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IPC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and provisions of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Protection of Children from Sexual Offenses (POCSO)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CRIME ACT SECTION</span>
# </mark>
#  Act in the case, he added.</div></span>
